# %% [markdown]
# # Aula 02: Estruturas de Decisão
#
# Até agora, nossos programas executaram todas as linhas de código, de cima para baixo. Mas e se a gente só quisesse executar um código se uma **condição** for verdadeira?
# Para isso usamos as estruturas de decisão, lideradas pelo comando `if` (se).

# %% [markdown]
# ## 1. O comando `if`
#
# O `if` verifica se uma afirmação é Verdadeira (`True`) ou Falsa (`False`). Se for Verdadeira, o bloco de código dentro do `if` é executado.

# %%
idade = 18

# Lê-se: Se idade for maior ou igual a 18...
if idade >= 18:
    print("Você é maior de idade.")
    print("Pode entrar na festa!")

print("Fim do programa.")
# Out:
# Você é maior de idade.
# Pode entrar na festa!
# Fim do programa.

# %%
idade= int(input("Digite sua idade"))
if idade>= 18:
  print(f"Você é maior de idade, a final vc tem: {idade} anos")
  print("Entra ai")
else:
 print("Lei felca pae")
# Out:
# Digite sua idade10
# Lei felca pae

# %% [markdown]
# **Atenção à indentação!** No Brasil, chamamos de "espaçamento". O Python usa espaços no começo da linha (indentação) para saber quais linhas de código pertencem ao `if`. Tudo que estiver alinhado com espaços para dentro faz parte daquele bloco.
#
# ### Operadores de Comparação:
# * `==` : Igual
# * `!=` : Diferente
# * `>`  : Maior que
# * `<`  : Menor que
# * `>=` : Maior ou igual a
# * `<=` : Menor ou igual a

# %% [markdown]
# ## 2. O comando `else` (Senão)
#
# Se a condição do `if` não for verdadeira, podemos usar o `else` para realizar outra ação.

# %%
nota = 5

if nota >= 7:
    print("Você foi Aprovado!")
else:
    print("Você foi Reprovado.")
# Out:
# Você foi Reprovado.

# %% [markdown]
# ## 3. O comando `elif` (Senão Se)
#
# Às vezes, temos mais de duas situações possíveis. Por exemplo, num semáforo de trânsito, temos verde, amarelo e vermelho. Usamos o `elif` para testar várias condições em sequência.

# %%
cor = input("Digite a cor do semáforo (verde/amarelo/vermelho): ").lower()

if cor == "verde":
    print("Siga em frente!")
elif cor == "amarelo":
    print("Atenção, diminua a velocidade.")
elif cor == "vermelho":
    print("Pare!")
else:
    print("Cor inválida.")
# Out:
# Digite a cor do semáforo (verde/amarelo/vermelho): verde
# Siga em frente!

# %% [markdown]
# No código acima, usamos `.lower()` ao final do `input()` para converter o que o usuário digitou para letras minúsculas (assim identificamos 'Verde', 'VERDE' ou 'verde' da mesma forma).

# %% [markdown]
# ## Exercício de Fixação
# Crie um código que pergunte um número inteiro ao usuário e informe na tela se esse número é **Positivo, Negativo ou Zero**.

# %%
# Escreva seu código de validação if/elif/else aqui
n = float(input("Digite um número inteiro: "))

if n>=1:
  print(f"{n} É um número maior que 0, ou seja positivo")
elif n==0:
  print(f"{n} É zero pow, numero neutro")
else:
  print(f"{n} É um numero menor que 0, ou seja negativo")
# Out:
# Digite um número inteiro: 2
# 2 É um número maior que 0, ou seja positivo

# %%
#_________________________________________________________________________________
#Teste Calculadora

import math
respUsuario= "s";
n1=0
n2=0
resultado=0
while respUsuario=="s":
  print("__________________________________________________")
  print("              Bem vindo a calculadora")
  print("__________________________________________________")
  print("1- Adição")
  print("2- Subtração")
  print("3- Divisão")
  print("4- Multiplicação")
  print("5- Exponenciação")
  print("6- Raiz Quadrada")
  menu=input("Qual operação você deseja fazer? ").lower()
  print("__________________________________________________")
  if menu=="1" or menu=="adição":
    n1=float(input("Qual o primeiro número?"))
    n2=float(input("Qual o segundo número?"))
    resultado= n1+n2
    print(f"O resultado dessa adição é: {resultado}")
    respUsuario=input("Deseja continuar?s/n ").lower()
    if respUsuario=="n":
      print("Adeus")
      print("__________________________________________________")
  elif menu=="2" or menu=="subtração":
    n1=float(input("Qual o primeiro número?"))
    n2=float(input("Qual o segundo número?"))
    resultado= n1-n2
    print(f"O resultado dessa subtração é: {resultado}")
    respUsuario=input("Deseja continuar?s/n ").lower()
    if respUsuario=="n":
      print("Adeus")
  elif menu=="3" or menu=="divisão":
    n1=float(input("Qual o divisor número?"))
    n2=float(input("Qual o dividendo número?"))
    if n1!=0 or n2!=0:
      resultado= n1/n2
      print(f"O resultado dessa divisão é: {resultado}")
      respUsuario=input("Deseja continuar?s/n ").lower()
      if respUsuario=="n":
        print("Adeus")
    else:
      print("Não é possível dividir por 0")

  elif menu=="4" or menu=="multiplicação":
    n1=float(input("Qual é o primeiro número?"))
    n2=float(input("Qual é o segundo número?"))
    resultado= n1*n2
    print(f"O resultado dessa multiplicação é: {resultado}")
    respUsuario=input("Deseja continuar?s/n ").lower()
    if respUsuario=="n":
      print("Adeus")
  elif menu=="5" or menu=="exponenciação":
    n1=float(input("Qual é o primeiro número?"))
    n2=float(input("Qual é o segundo número?"))
    resultado= n1**n2
    print(f"O resultado dessa exponenciação é: {resultado}")
    respUsuario=input("Deseja continuar?s/n ").lower()
    if respUsuario=="n":
      print("Adeus")
  elif menu=="6" or menu=="raiz quadrada":
    n1=float(input("Qual é o primeiro número?"))
    resultado= math.sqrt(n1)
    print(f"Raiz Quardrada de {n1} é: {resultado}")
    respUsuario=input("Deseja continuar?s/n ").lower()
    if respUsuario=="n":
      print("Adeus")
  else:
    print("Adeus")
